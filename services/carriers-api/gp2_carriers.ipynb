# %%
import pandas as pd
import glob

# %%
plink2 = '/home/vitaled2/.genotools/misc/executables/plink2'
project_dir = '/home/vitaled2/gp2_carriers'
data_dir = f'{project_dir}/data'
report_path = f'{data_dir}/NBA_Report.csv'
geno_dir = f'{data_dir}/raw_genotypes'
labels = ['AAC', 'AFR', 'AJ', 'AMR', 'CAH', 'CAS', 'EAS', 'EUR', 'FIN','MDE', 'SAS']
key = pd.read_csv(f'data/nba_app_key.csv')

# %%
# get snps list
report = pd.read_csv(report_path)
report.columns = [x.strip() for x in report.columns]
report.drop(columns=['GP2ID','Cohort Code', 'Local ID',	'PI','PD EUR PRS (GWAS vXX)','NBA derived Ancestry'], inplace=True)

snp_df = report.loc[~report['Unnamed: 0'].isna()]
snp_df.set_index('Unnamed: 0', inplace=True)
snp_df = snp_df.transpose()
snp_df.reset_index(inplace=True)
snp_df.rename(columns={'index':'snp'}, inplace=True)
snp_df.drop(columns=['Alternative variant name'], inplace=True)
snp_df.columns.name = None
snp_df.columns = ['snp','rsid','hg19','hg38','ancestry']
snp_df = snp_df.loc[~snp_df.hg38.isna()]

pvar_total = pd.DataFrame()
for label in labels:
    label_geno_path = f'{geno_dir}/{label}/{label}_release9_vwb'
    pvar = pd.read_csv(f'{label_geno_path}.pvar', sep='\t', dtype={'#CHROM':str})
    pvar.columns = ['chrom', 'pos', 'id', 'a1', 'a2']
    pvar.loc[:,'snpid1'] = pvar['chrom'] + ':' + pvar['pos'].astype(str) + ':' + pvar['a1'] + ':' + pvar['a2']
    pvar.loc[:,'snpid2'] = pvar['chrom'] + ':' + pvar['pos'].astype(str) + ':' + pvar['a2'] + ':' + pvar['a1']
    pvar_sub1 = pvar.loc[pvar['snpid1'].isin(snp_df['hg38'])].copy()
    pvar_sub1.loc[:,'snpid'] = pvar_sub1['snpid1']
    pvar_sub2 = pvar.loc[pvar['snpid2'].isin(snp_df['hg38'])].copy()
    pvar_sub2.loc[:,'snpid'] = pvar_sub2['snpid2']
    pvar_total = pd.concat([pvar_total, pvar_sub1, pvar_sub2], ignore_index=True)
pvar_total.drop(columns=['snpid1','snpid2'], inplace=True)

# pvar_total[['id']].drop_duplicates().to_csv(f'{data_dir}/snps.txt', header=False, index=False)

snp_df_out = pvar_total.merge(snp_df, how='left', left_on='snpid', right_on='hg38')
snp_df_out.drop(columns=['chrom', 'pos', 'a1', 'a2'], inplace=True)
snp_df_out.rename(columns={'snp':'variant'}, inplace=True)

snp_df_out['snp_name'] = snp_df_out['variant'].str.extract(f'\((.*?)\)')

snp_df_out.loc[:,'locus'] = snp_df_out.variant.str.split(' ', expand=True)[:][0]
snp_df_out.loc[:,'snp_name_full'] = snp_df_out['locus'] + '_' + snp_df_out['snp_name'] + '_' + snp_df_out['id']
snp_df_out.drop(columns=['snpid'], inplace=True)
snp_df_out.drop_duplicates(inplace=True)
snp_df_out.to_csv(f'{data_dir}/snps_out.csv', index=False)

# %%
from carriers_api.app.carriers import extract_carriers, combine_carrier_files

output_dir = f'{data_dir}/api_test/outputs'

results_by_label = {}
for label in labels:
    results = extract_carriers(
        geno_path=f'{geno_dir}/{label}/{label}_release9_vwb',
        snplist_path=f'{data_dir}/snps_out.csv',
        out_path=f'{output_dir}/{label}',
        return_dfs=True
    )
    results_by_label[label] = results

combined_results = combine_carrier_files(
    results_by_label=results_by_label,
    key_file=f'{data_dir}/nba_app_key.csv',
    output_dir=output_dir
)
# Out:
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb
#
# Start time: Fri Feb 14 18:48:04 2025
# 32105 MiB RAM detected, ~30169 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1230 samples (724 females, 506 males; 1230 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb.psam.
# 1896835 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb.pvar.
# 1 binary phenotype loaded (341 cases, 837 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AAC/AAC_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:04 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb
#
# Start time: Fri Feb 14 18:48:04 2025
# 32105 MiB RAM detected, ~30178 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 2767 samples (1244 females, 1523 males; 2767 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb.psam.
# 1788859 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb.pvar.
# 1 binary phenotype loaded (992 cases, 1730 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AFR/AFR_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:05 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb
#
# Start time: Fri Feb 14 18:48:05 2025
# 32105 MiB RAM detected, ~30167 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 3251 samples (1213 females, 2038 males; 3251 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb.psam.
# 1875579 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb.pvar.
# 1 binary phenotype loaded (1497 cases, 431 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb_snps.afreq .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AJ/AJ_release9_vwb_snps.traw ...
# 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:06 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb
#
# Start time: Fri Feb 14 18:48:07 2025
# 32105 MiB RAM detected, ~30164 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 3581 samples (1879 females, 1702 males; 3581 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb.psam.
# 1843508 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb.pvar.
# 1 binary phenotype loaded (1972 cases, 1457 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/AMR/AMR_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:07 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb
#
# Start time: Fri Feb 14 18:48:08 2025
# 32105 MiB RAM detected, ~30168 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1034 samples (493 females, 541 males; 1034 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb.psam.
# 1904683 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb.pvar.
# 1 binary phenotype loaded (668 cases, 322 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAH/CAH_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:08 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb
#
# Start time: Fri Feb 14 18:48:09 2025
# 32105 MiB RAM detected, ~30158 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 1089 samples (578 females, 511 males; 1089 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb.psam.
# 1902516 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb.pvar.
# 1 binary phenotype loaded (617 cases, 347 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/CAS/CAS_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:09 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb
#
# Start time: Fri Feb 14 18:48:09 2025
# 32105 MiB RAM detected, ~30159 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 5902 samples (2251 females, 3651 males; 5902 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb.psam.
# 1730431 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb.pvar.
# 1 binary phenotype loaded (1882 cases, 2445 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EAS/EAS_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:09 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb
#
# Start time: Fri Feb 14 18:48:11 2025
# 32105 MiB RAM detected, ~30152 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 51247 samples (22571 females, 28676 males; 51247 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb.psam.
# 1668646 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb.pvar.
# 1 binary phenotype loaded (23198 cases, 10230 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/EUR/EUR_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:48:12 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb
#
# Start time: Fri Feb 14 18:49:12 2025
# 32105 MiB RAM detected, ~30021 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 137 samples (78 females, 59 males; 137 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb.psam.
# 1883041 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb.pvar.
# 1 binary phenotype loaded (106 cases, 9 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/FIN/FIN_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:49:12 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb
#
# Start time: Fri Feb 14 18:49:12 2025
# 32105 MiB RAM detected, ~30025 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 866 samples (336 females, 530 males; 866 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb.psam.
# 1888776 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb.pvar.
# 1 binary phenotype loaded (477 cases, 224 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/MDE/MDE_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:49:12 2025
# PLINK v2.0.0-a.6.3LM AVX2 Intel (3 Dec 2024)       cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb_snps.log.
# Options in effect:
#   --export Av
#   --extract /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb_temp_snps.txt
#   --freq
#   --out /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb_snps
#   --pfile /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb
#
# Start time: Fri Feb 14 18:49:12 2025
# 32105 MiB RAM detected, ~30018 available; reserving 16052 MiB for main
# workspace.
# Using up to 8 compute threads.
# 731 samples (262 females, 469 males; 731 founders) loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb.psam.
# 1919616 variants loaded from
# /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb.pvar.
# 1 binary phenotype loaded (235 cases, 217 controls).
# --extract: 24 variants remaining.
# Calculating allele frequencies... 252941done.
# --freq: Allele frequencies (founders only) written to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb_snps.afreq
# .
# 24 variants remaining after main filters.
# --export Av to
# /home/vitaled2/gp2_carriers/data/raw_genotypes/SAS/SAS_release9_vwb_snps.traw
# ... 121620252933374145505458626670757983879195done.
# End time: Fri Feb 14 18:49:13 2025

# %%
carriers_string = pd.read_csv(combined_results['carriers_string'])
var_info = pd.read_csv(combined_results['var_info'])
var_info
# Out:
#                                    id         rsid             hg19  \
# 0                     1:155204987-C-T   rs80356771  1:155204987:G:A
# 1   Seq_rs80356771.1_ilmnrev_ilmnF2BT   rs80356771  1:155204987:G:A
# 2                          rs80356771   rs80356771  1:155204987:G:A
# 3                           exm106220   rs75548401  1:155206037:G:A
# 4                          rs75548401   rs75548401  1:155206037:G:A
# 5                      seq_rs75548401   rs75548401  1:155206037:G:A
# 6   Seq_rs34424986.1_ilmnrev_ilmnF2BT   rs34424986              NaN
# 7                           exm593505   rs34424986              NaN
# 8                          rs34424986   rs34424986              NaN
# 9                     12:40692927-A-G   rs34805604              NaN
# 10                     Seq_rs34805604   rs34805604              NaN
# 11  Seq_rs33939927.1_ilmnfwd_ilmnF2BT   rs33939927              NaN
# 12  Seq_rs33939927.2_ilmnfwd_ilmnF2BT   rs33939927  12:40704236:C:G
# 13                    12:40704237-G-A   rs34995376  12:40704237:G:A
# 14                     Seq_rs34995376   rs34995376  12:40704237:G:A
# 15                    12:40714916-A-G   rs35801418              NaN
# 16                     Seq_rs35801418   rs35801418              NaN
# 17                          exm994671   rs34637584  12:40734202:G:A
# 18                         rs34637584   rs34637584  12:40734202:G:A
# 19                     seq_rs34637584   rs34637584  12:40734202:G:A
# 20                          exm994721   rs34778348  12:40757328:G:A
# 21                         rs34778348   rs34778348  12:40757328:G:A
# 22                     seq_rs34778348   rs34778348  12:40757328:G:A
# 23                        rs104893878  rs104893878              NaN
#
#                hg38    ancestry  CHR                                SNP  (C)M  \
# 0   1:155235196:G:A         NaN    1                    1:155204987-C-T     0
# 1   1:155235196:G:A         NaN    1  Seq_rs80356771.1_ilmnrev_ilmnF2BT     0
# 2   1:155235196:G:A         NaN    1                         rs80356771     0
# 3   1:155236246:G:A  AMISH/ EUR    1                          exm106220     0
# 4   1:155236246:G:A  AMISH/ EUR    1                         rs75548401     0
# 5   1:155236246:G:A  AMISH/ EUR    1                     seq_rs75548401     0
# 6   6:161785820:G:A        MULT    6  Seq_rs34424986.1_ilmnrev_ilmnF2BT     0
# 7   6:161785820:G:A        MULT    6                          exm593505     0
# 8   6:161785820:G:A        MULT    6                         rs34424986     0
# 9   12:40299125:A:G        MULT   12                    12:40692927-A-G     0
# 10  12:40299125:A:G        MULT   12                     Seq_rs34805604     0
# 11  12:40310434:C:A        MULT   12  Seq_rs33939927.1_ilmnfwd_ilmnF2BT     0
# 12  12:40310434:C:G        MULT   12  Seq_rs33939927.2_ilmnfwd_ilmnF2BT     0
# 13  12:40310435:G:A        MULT   12                    12:40704237-G-A     0
# 14  12:40310435:G:A        MULT   12                     Seq_rs34995376     0
# 15  12:40321114:A:G        MULT   12                    12:40714916-A-G     0
# 16  12:40321114:A:G        MULT   12                     Seq_rs35801418     0
# 17  12:40340400:G:A    AJ/ EUR    12                          exm994671     0
# 18  12:40340400:G:A    AJ/ EUR    12                         rs34637584     0
# 19  12:40340400:G:A    AJ/ EUR    12                     seq_rs34637584     0
# 20  12:40363526:G:A         EAS   12                          exm994721     0
# 21  12:40363526:G:A         EAS   12                         rs34778348     0
# 22  12:40363526:G:A         EAS   12                     seq_rs34778348     0
# 23   4:89835580:C:G         EUR    4                        rs104893878     0
#
#           POS COUNTED  ... ALT_FREQS_EAS OBS_CT_EAS ALT_FREQS_EUR OBS_CT_EUR  \
# 0   155235196       G  ...      0.001949      11800      0.000664     102480
# 1   155235196       G  ...      0.001949      11798      0.000684     102394
# 2   155235196       G  ...      0.001949      11798      0.000683     102492
# 3   155236246       G  ...      0.000339      11798      0.012223     102434
# 4   155236246       G  ...      0.000254      11788      0.012061     102226
# 5   155236246       G  ...      0.000254      11804      0.012260     102446
# 6   161785820       G  ...      0.000000      11796      0.001060     101902
# 7   161785820       G  ...      0.000170      11794      0.003641     102452
# 8   161785820       G  ...      0.000085      11798      0.003815     102480
# 9    40299125       A  ...      0.000000      11802      0.000000     102486
# 10   40299125       A  ...      0.000000      11804      0.000010     102478
# 11   40310434       C  ...      0.000085      11800      0.000020     102474
# 12   40310434       C  ...      0.000000      11798      0.000927     102478
# 13   40310435       G  ...      0.000169      11804      0.000107     102476
# 14   40310435       G  ...      0.000169      11802      0.000107     102480
# 15   40321114       A  ...      0.000000      11784      0.000049     102302
# 16   40321114       A  ...      0.000000      11800      0.000029     102434
# 17   40340400       G  ...      0.000085      11802      0.004225     102484
# 18   40340400       G  ...      0.000085      11804      0.004225     102480
# 19   40340400       G  ...      0.000085      11802      0.004235     102486
# 20   40363526       G  ...      0.031271      11800      0.000068     102474
# 21   40363526       G  ...      0.031276      11798      0.000059     102450
# 22   40363526       G  ...      0.031276      11798      0.000078     102400
# 23   89835580       G  ...      0.000000      11804      0.000000     102474
#
#     ALT_FREQS_FIN OBS_CT_FIN ALT_FREQS_MDE OBS_CT_MDE  ALT_FREQS_SAS  \
# 0        0.000000        274      0.000000       1732       0.000000
# 1        0.000000        274      0.000000       1732       0.000000
# 2        0.000000        274      0.000000       1732       0.000000
# 3        0.029412        272      0.000577       1732       0.000684
# 4        0.033088        272      0.000579       1728       0.000685
# 5        0.029412        272      0.000577       1732       0.000684
# 6        0.000000        274      0.000000       1732       0.000000
# 7        0.000000        274      0.000000       1732       0.000684
# 8        0.000000        274      0.000000       1732       0.000684
# 9        0.000000        274      0.000000       1732       0.000000
# 10       0.000000        274      0.000000       1732       0.000000
# 11       0.000000        274      0.000000       1732       0.000000
# 12       0.000000        274      0.000000       1732       0.000000
# 13       0.000000        274      0.000000       1732       0.000000
# 14       0.000000        274      0.000000       1732       0.000000
# 15       0.000000        272      0.000000       1730       0.000000
# 16       0.000000        272      0.000000       1730       0.000000
# 17       0.000000        274      0.039838       1732       0.000000
# 18       0.000000        274      0.039838       1732       0.000000
# 19       0.000000        274      0.039838       1732       0.000000
# 20       0.000000        274      0.000000       1730       0.000000
# 21       0.000000        274      0.000000       1730       0.000000
# 22       0.000000        274      0.000000       1728       0.000000
# 23       0.000000        274      0.000000       1732       0.000000
#
#     OBS_CT_SAS
# 0         1462
# 1         1460
# 2         1462
# 3         1462
# 4         1460
# 5         1462
# 6         1460
# 7         1462
# 8         1462
# 9         1462
# 10        1462
# 11        1462
# 12        1462
# 13        1462
# 14        1462
# 15        1460
# 16        1462
# 17        1462
# 18        1462
# 19        1462
# 20        1462
# 21        1462
# 22        1460
# 23        1462
#
# [24 rows x 40 columns]

# %%
carriers_string[carriers_string['GBA1_p.R502C_1:155204987-C-T']!='WT/WT']
# Out:
#                       IID        study ancestry GBA1_p.R502C_1:155204987-C-T  \
# 32     BLAACPD-KPM_000032  BLAACPD-KPM      AAC                   WT/p.R502C
# 1412   BLAACPD-UFL_000002  BLAACPD-UFL      AFR                   WT/p.R502C
# 5121           LCC_000008          LCC       AJ                          ./.
# 9269       LARGEPD_001828      LARGEPD      AMR                          ./.
# 10689      PDGNRTN_007257      PDGNRTN      AMR                   WT/p.R502C
# ...                   ...          ...      ...                          ...
# 69623         VIPD_000214         VIPD      EUR                   WT/p.R502C
# 69760         VIPD_000369         VIPD      EUR                   WT/p.R502C
# 69881         VIPD_000512         VIPD      EUR                   WT/p.R502C
# 70045         VIPD_000741         VIPD      EUR                   WT/p.R502C
# 70095          YMS_000047          YMS      EUR                   WT/p.R502C
#
#       GBA1_p.R502C_Seq_rs80356771.1_ilmnrev_ilmnF2BT GBA1_p.R502C_rs80356771  \
# 32                                        WT/p.R502C              WT/p.R502C
# 1412                                      WT/p.R502C              WT/p.R502C
# 5121                                           WT/WT                   WT/WT
# 9269                                           WT/WT                   WT/WT
# 10689                                     WT/p.R502C              WT/p.R502C
# ...                                              ...                     ...
# 69623                                     WT/p.R502C              WT/p.R502C
# 69760                                     WT/p.R502C              WT/p.R502C
# 69881                                     WT/p.R502C              WT/p.R502C
# 70045                                     WT/p.R502C              WT/p.R502C
# 70095                                     WT/p.R502C              WT/p.R502C
#
#       GBA1_p.T408M_exm106220 GBA1_p.T408M_rs75548401  \
# 32                     WT/WT                   WT/WT
# 1412                   WT/WT                   WT/WT
# 5121                   WT/WT                   WT/WT
# 9269                   WT/WT                   WT/WT
# 10689                  WT/WT                   WT/WT
# ...                      ...                     ...
# 69623                  WT/WT                   WT/WT
# 69760                  WT/WT                   WT/WT
# 69881                  WT/WT                   WT/WT
# 70045                  WT/WT                   WT/WT
# 70095                  WT/WT                   WT/WT
#
#       GBA1_p.T408M_seq_rs75548401  \
# 32                          WT/WT
# 1412                        WT/WT
# 5121                        WT/WT
# 9269                        WT/WT
# 10689                       WT/WT
# ...                           ...
# 69623                       WT/WT
# 69760                       WT/WT
# 69881                       WT/WT
# 70045                       WT/WT
# 70095                       WT/WT
#
#       PRKN_R275W_Seq_rs34424986.1_ilmnrev_ilmnF2BT  ...  \
# 32                                           WT/WT  ...
# 1412                                         WT/WT  ...
# 5121                                         WT/WT  ...
# 9269                                         WT/WT  ...
# 10689                                        WT/WT  ...
# ...                                            ...  ...
# 69623                                        WT/WT  ...
# 69760                                        WT/WT  ...
# 69881                                        WT/WT  ...
# 70045                                        WT/WT  ...
# 70095                                        WT/WT  ...
#
#       LRRK2_R1441H_Seq_rs34995376 LRRK2_Y1699C_12:40714916-A-G  \
# 32                          WT/WT                        WT/WT
# 1412                        WT/WT                        WT/WT
# 5121                        WT/WT                        WT/WT
# 9269                        WT/WT                        WT/WT
# 10689                       WT/WT                        WT/WT
# ...                           ...                          ...
# 69623                       WT/WT                        WT/WT
# 69760                       WT/WT                        WT/WT
# 69881                       WT/WT                        WT/WT
# 70045                       WT/WT                        WT/WT
# 70095                       WT/WT                        WT/WT
#
#       LRRK2_Y1699C_Seq_rs35801418 LRRK2_G2019S_exm994671  \
# 32                          WT/WT                  WT/WT
# 1412                        WT/WT                  WT/WT
# 5121                        WT/WT              WT/G2019S
# 9269                        WT/WT                  WT/WT
# 10689                       WT/WT                  WT/WT
# ...                           ...                    ...
# 69623                       WT/WT                  WT/WT
# 69760                       WT/WT                  WT/WT
# 69881                       WT/WT                  WT/WT
# 70045                       WT/WT                  WT/WT
# 70095                       WT/WT                  WT/WT
#
#       LRRK2_G2019S_rs34637584 LRRK2_G2019S_seq_rs34637584  \
# 32                      WT/WT                       WT/WT
# 1412                    WT/WT                       WT/WT
# 5121                WT/G2019S                   WT/G2019S
# 9269                    WT/WT                       WT/WT
# 10689                   WT/WT                       WT/WT
# ...                       ...                         ...
# 69623                   WT/WT                       WT/WT
# 69760                   WT/WT                       WT/WT
# 69881                   WT/WT                       WT/WT
# 70045                   WT/WT                       WT/WT
# 70095                   WT/WT                       WT/WT
#
#       LRRK2_G2385D_exm994721 LRRK2_G2385D_rs34778348  \
# 32                     WT/WT                   WT/WT
# 1412                   WT/WT                   WT/WT
# 5121                   WT/WT                   WT/WT
# 9269                   WT/WT                   WT/WT
# 10689                  WT/WT                   WT/WT
# ...                      ...                     ...
# 69623                  WT/WT                   WT/WT
# 69760                  WT/WT                   WT/WT
# 69881                  WT/WT                   WT/WT
# 70045                  WT/WT                   WT/WT
# 70095                  WT/WT                   WT/WT
#
#       LRRK2_G2385D_seq_rs34778348 SNCA_A30P_rs104893878
# 32                          WT/WT                 WT/WT
# 1412                        WT/WT                 WT/WT
# 5121                        WT/WT                 WT/WT
# 9269                        WT/WT                 WT/WT
# 10689                       WT/WT                 WT/WT
# ...                           ...                   ...
# 69623                       WT/WT                 WT/WT
# 69760                       WT/WT                 WT/WT
# 69881                       WT/WT                 WT/WT
# 70045                       WT/WT                 WT/WT
# 70095                       WT/WT                 WT/WT
#
# [106 rows x 27 columns]

# %%
def verify_genotype(raw_value, string_value, snp_name):
    if pd.isna(raw_value):
        return string_value == './.'
    raw_value = int(raw_value)
    if raw_value == 2:
        return string_value == "WT/WT"
    elif raw_value == 1:
        return string_value.startswith("WT/")
    elif raw_value == 0:
        return string_value.count(snp_name.split('_')[1]) == 2
    else:
        return string_value == ":/:"

def validate_carrier_data(traw_dir, combined_file, snp_info_file, samples_to_check=None):
    """
    Validate that combined carrier data matches original traw files.
    
    Args:
        traw_dir: Directory containing traw files
        combined_file: Path to combined carriers file
        snp_info_file: Path to SNP info file
        samples_to_check: List of sample IDs to check (None for all)
    """
    carriers = pd.read_csv(combined_file)
    snp_df = pd.read_csv(snp_info_file)
    
    if samples_to_check is None:
        samples_to_check = carriers['IID'].unique()[:5]  # Check first 5 samples by default
    
    mismatches = []
    for sample_id in samples_to_check:
        # Get ancestry for this sample
        ancestry = carriers.loc[carriers['IID'] == sample_id, 'ancestry'].iloc[0]
        
        # Read corresponding traw file
        traw_path = f'{traw_dir}/{ancestry}/{ancestry}_release9_vwb_snps.traw'
        traw = pd.read_csv(traw_path, sep='\t')
        traw_merged = snp_df.merge(traw, how='left', left_on='id', right_on='SNP')
        
        # Check each SNP
        for snp in snp_df['snp_name_full']:
            raw_value = traw_merged.loc[
                traw_merged['snp_name_full'] == snp, 
                f'0_{sample_id}'
            ].iloc[0]
            
            combined_value = carriers.loc[
                carriers['IID'] == sample_id,
                snp
            ].iloc[0]
            
            if not verify_genotype(raw_value, combined_value, snp):
                mismatches.append({
                    'sample': sample_id,
                    'ancestry': ancestry,
                    'snp': snp,
                    'raw': raw_value,
                    'combined': combined_value
                })
    
    if mismatches:
        print("Found mismatches:")
        print(pd.DataFrame(mismatches))
    else:
        print("All checked genotypes match!")

# Use it like this:
validate_carrier_data(
    traw_dir=geno_dir,
    combined_file=f'{output_dir}/carriers_string_full.csv',
    snp_info_file=f'{data_dir}/snps_out.csv',
    samples_to_check=['BLAACPD-KPM_000032']
)
# Out:
# All checked genotypes match!

# %%
# from carriers_api.app.carriers import extract_carriers

# output_dir = f'{data_dir}/api_test/outputs'
# carriers_string_full_path = f'{output_dir}/carriers_string_full.csv'
# carriers_int_full_path = f'{output_dir}/carriers_int_full.csv'
# var_info_full_path = f'{output_dir}/var_info_full.csv'

# carriers_string_full = pd.DataFrame()
# carriers_int_full = pd.DataFrame()
# label_var_info_full = pd.DataFrame()

# for label in labels:
#     results = extract_carriers(
#         geno_path=f'{geno_dir}/{label}/{label}_release9_vwb',
#         snplist_path=f'{data_dir}/snps_out.csv',
#         out_path=f'{output_dir}/{label}'
#     )

#     label_carriers_string = results['carriers_string']
#     label_carriers_int = results['carriers_int']
#     label_var_info = results['var_info']

#     label_var_info_full = pd.concat([label_var_info_full, label_var_info], ignore_index=True)

#     carriers_string = pd.read_csv(label_carriers_string)
#     carriers_string['IID'] = carriers_string['IID'].str.replace('0_', '')
#     carriers_string.loc[:,'ancestry'] = label
#     carriers_string_full = pd.concat([carriers_string_full, carriers_string], ignore_index=True)
    
#     carriers_int = pd.read_csv(label_carriers_int)
#     carriers_int['IID'] = carriers_int['IID'].str.replace('0_', '')
#     carriers_int.loc[:,'ancestry'] = label
#     carriers_int_full = pd.concat([carriers_int_full, carriers_int], ignore_index=True)

# variant_columns = [x for x in carriers_string_full.columns if x not in ['IID','ancestry']]
# carriers_string_full_out = carriers_string_full[['IID', 'ancestry'] + variant_columns]
# carriers_string_full_out[variant_columns] = carriers_string_full_out[variant_columns].fillna('./.')
# carriers_string_full_out_merge = carriers_string_full_out.merge(key[['IID','study']], how='left', on='IID')
# carriers_string_final = carriers_string_full_out_merge[['IID', 'study', 'ancestry'] + variant_columns]
# carriers_string_final.to_csv(carriers_string_full_path, index=False)

# # Process and save final integer format
# carriers_int_full_out = carriers_int_full[['IID', 'ancestry'] + [x for x in carriers_int_full.columns if x not in ['IID','ancestry']]]
# carriers_int_full_out_merge = carriers_int_full_out.merge(key[['IID','study']], how='left', on='IID')
# carriers_int_final = carriers_int_full_out_merge[['IID', 'study', 'ancestry'] + variant_columns]
# carriers_int_final.to_csv(carriers_int_full_path, index=False)

# %%
# carriers_string_full_path = f'{data_dir}/api_test/outputs/carriers_string_full.csv'
# carriers_int_full_path = f'{data_dir}/api_test/outputs/carriers_int_full.csv'

# carriers_string_full = pd.DataFrame()
# carriers_int_full = pd.DataFrame()

# for label in labels:
#     label_carriers_string = f'{data_dir}/api_test/outputs/{label}_carriers_string.csv'
#     label_carriers_int = f'{data_dir}/api_test/outputs/{label}_carriers_int.csv'
    
#     carriers_string = pd.read_csv(label_carriers_string)
#     carriers_string['IID'] = carriers_string['IID'].str.replace('0_', '')
#     carriers_string.loc[:,'ancestry'] = label
#     carriers_string_full = pd.concat([carriers_string_full, carriers_string], ignore_index=True)
    
#     carriers_int = pd.read_csv(label_carriers_int)
#     carriers_int['IID'] = carriers_int['IID'].str.replace('0_', '')
#     carriers_int.loc[:,'ancestry'] = label
#     carriers_int_full = pd.concat([carriers_int_full, carriers_int], ignore_index=True)

# # Process and save final string format
# variant_columns = [x for x in carriers_string_full.columns if x not in ['IID','ancestry']]
# carriers_string_full_out = carriers_string_full[['IID', 'ancestry'] + variant_columns]
# carriers_string_full_out[variant_columns] = carriers_string_full_out[variant_columns].fillna('./.')
# carriers_string_full_out_merge = carriers_string_full_out.merge(key[['IID','study']], how='left', on='IID')
# carriers_string_final = carriers_string_full_out_merge[['IID', 'study', 'ancestry'] + variant_columns]
# carriers_string_final.to_csv(carriers_string_full_path, index=False)

# # Process and save final integer format
# carriers_int_full_out = carriers_int_full[['IID', 'ancestry'] + [x for x in carriers_int_full.columns if x not in ['IID','ancestry']]]
# carriers_int_full_out_merge = carriers_int_full_out.merge(key[['IID','study']], how='left', on='IID')
# carriers_int_final = carriers_int_full_out_merge[['IID', 'study', 'ancestry'] + variant_columns]
# carriers_int_final.to_csv(carriers_int_full_path, index=False)

# %%
# replaced by modules in carriers.py

# for label in labels:
#     label_geno_path = f'{geno_dir}/{label}/{label}_release9_vwb'
#     label_snps_traw = f'{label_geno_path}_snps.traw'
#     label_snps_afreq = f'{label_geno_path}_snps.afreq'
#     label_carriers_var_info = f'{data_dir}/outputs/{label}_carriers_var_info.csv'
#     label_carriers_string = f'{data_dir}/outputs/{label}_carriers_string.csv'
#     label_carriers_int = f'{data_dir}/outputs/{label}_carriers_int.csv'

#     snp_df = pd.read_csv(f'{data_dir}/snps_out.csv')
#     snp_df['id'].to_csv(f'{data_dir}/{label}_snps.txt', header=False, index=False)

#     extract_cmd = f"plink2 --pfile {label_geno_path} --extract {data_dir}/{label}_snps.txt --export Av --freq --out {label_geno_path}_snps"
#     !{extract_cmd}
    
#     traw = pd.read_csv(label_snps_traw, sep='\t')
#     traw_merged = snp_df.merge(traw, how='left', left_on='id', right_on='SNP')
    
#     colnames = [
#         'id',
#         'rsid',
#         'hg19',
#         'hg38',
#         'ancestry', 
#         'CHR',
#         'SNP', 
#         '(C)M', 
#         'POS',
#         'COUNTED',
#         'ALT',
#         'variant',
#         'snp_name', 
#         'locus', 
#         'snp_name_full'
#         ]
#     var_cols = [x for x in colnames if x not in ['snp_name_full']]
#     sample_cols = list(traw_merged.drop(columns=colnames).columns)

#     traw_final = traw_merged.loc[:, colnames + sample_cols]
    
#     traw_out = traw_final.copy()
#     traw_out[sample_cols] = traw_out.apply(
#         lambda row: [genotype_to_string(row[col], row['snp_name']) for col in sample_cols],
#         axis=1,
#         result_type='expand'
#     )

#     gt_df = traw_final.drop(columns=var_cols).set_index('snp_name_full').T.reset_index()
#     gt_df.columns.name = None
#     gt_df.rename(columns={'index':'IID'}, inplace=True)

#     # Process and save frequency info
#     freq = pd.read_csv(label_snps_afreq, sep='\t')
#     freq.rename(columns={'ID':'SNP'}, inplace=True)
#     var_info_df = traw_final.loc[:,var_cols]
#     var_info_df.merge(freq, how='left', on='SNP')
#     var_info_df.to_csv(label_carriers_var_info, index=False)
    
#     # Process and save string format
#     carriers_string = traw_out.drop(columns=var_cols).set_index('snp_name_full').T.reset_index()
#     carriers_string.columns.name = None
#     carriers_string = carriers_string.fillna('./.')
#     carriers_string = carriers_string.astype(str)
#     carriers_string.rename(columns={'index':'IID'}, inplace=True)
#     carriers_string.to_csv(label_carriers_string, index=False)

#     # Process and save integer format
#     carriers_int = traw_final.drop(columns=var_cols).set_index('snp_name_full').T.reset_index()
#     carriers_int.columns.name = None
#     carriers_int.rename(columns={'index':'IID'}, inplace=True)
#     carriers_int.to_csv(label_carriers_int, index=False)

# %%
# !gcloud storage cp {data_dir}/outputs/carriers_string_full.csv gs://gp2_carriers/
# !gcloud storage cp {data_dir}/outputs/carriers_int_full.csv gs://gp2_carriers/
